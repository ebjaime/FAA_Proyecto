# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
sensor_m = pd.read_csv("data/HT_Sensor_metadata.dat", sep="\t")
# Correccion: cabecera de metadata mal leido
sensor_m.drop(["dt"], axis=1, inplace=True)
sensor_m.rename(columns={"t0":"dt","class":"t0", "Unnamed: 2":"class"}, inplace=True)

columns_metadata = ["id", "date", "class", "t0", "dt"]
metadata = np.loadtxt('data/HT_Sensor_metadata.dat', skiprows=1, dtype=str)
metadata_aux = np.array( metadata[:,[0,3,4]], dtype=float )

# %%
sensor_d = pd.read_csv("data/HT_Sensor_dataset.dat", sep="  ", engine="python")
# Correccion: datos de dataset mal leidos
sensor_d.dropna(axis=1, inplace=True)
sensor_d.columns=["id","time", "R1","R2","R3","R4","R5","R6","R7","R8", "Temp.", "Humidity"]

columns_dataset = ["id","time", "R1","R2","R3","R4","R5","R6","R7","R8", "Temp.", "Humidity"]
dataset = np.loadtxt('data/HT_Sensor_dataset.dat', skiprows=1)

# %%
def dataframe_medias_varianzas_por_id(sensor_d=sensor_d):
    dict_aux = {}
    for induction in sensor_d.id.unique():
        aux = []
        aux.append(induction)
        for attr in sensor_d.columns[2:12]:
            aux.append(sensor_d[sensor_d.id==induction][attr].mean())
            aux.append(sensor_d[sensor_d.id==induction][attr].var())
        dict_aux[induction] = aux
    return pd.DataFrame.from_dict(dict_aux, orient='index',columns=["id","R1_mean","R1_var","R2_mean",
                                                                "R2_var","R3_mean","R3_var","R4_mean",
                                                                "R4_var","R5_mean","R5_var","R6_mean","R6_var",
                                                                "R7_mean","R7_var","R8_mean","R8_var",
                                                                "Temp._mean","Temp._var",
                                                                "Humidity_mean", "Humidity_var"])

# %%
dataframe = dataframe_medias_varianzas_por_id()

dataframe_banana = dataframe.loc[dataframe['id'].isin(sensor_m[sensor_m['class'] == "banana"]['id'])]
dataframe_wine = dataframe.loc[dataframe['id'].isin(sensor_m[sensor_m['class'] == "wine"]['id'])]
dataframe_background = dataframe.loc[dataframe['id'].isin(sensor_m[sensor_m['class'] == "background"]['id'])]

dataframe2 = sensor_d[sensor_d["Temp."]>29]

dataframe_banana2 = dataframe2.loc[dataframe2['id'].isin(sensor_m[sensor_m['class'] == "banana"]['id'])]
dataframe_wine2 = dataframe2.loc[dataframe2['id'].isin(sensor_m[sensor_m['class'] == "wine"]['id'])]
dataframe_background2 = dataframe2.loc[dataframe2['id'].isin(sensor_m[sensor_m['class'] == "background"]['id'])]

dataframe3 = sensor_d[sensor_d["Temp."]<25]

dataframe_banana3 = dataframe3.loc[dataframe3['id'].isin(sensor_m[sensor_m['class'] == "banana"]['id'])]
dataframe_wine3 = dataframe3.loc[dataframe3['id'].isin(sensor_m[sensor_m['class'] == "wine"]['id'])]
dataframe_background3 = dataframe3.loc[dataframe3['id'].isin(sensor_m[sensor_m['class'] == "background"]['id'])]

# %%
fig, ax = plt.subplots(8,2, figsize=(10, 50))
fig.tight_layout()
fig.subplots_adjust(left=0.25, bottom=0.15, hspace=1) 

ax[0,0].scatter(dataframe_banana["Temp._mean"],dataframe_banana["R1_mean"])
ax[0,0].set_xlabel ('Temperatura media')
ax[0,0].set_ylabel('Valores sensor')
ax[0,0].set_title ('Gráfica sensor 1')
ax[0,1].scatter(dataframe_banana["Humidity_mean"],dataframe_banana["R1_mean"])
ax[0,1].set_xlabel ('Humedad media')
ax[0,1].set_ylabel('Valores sensor')
ax[0,1].set_title ('Gráfica sensor 1')
ax[1,0].scatter(dataframe_banana["Temp._mean"],dataframe_banana["R2_mean"])
ax[1,0].set_xlabel ('Temperatura media')
ax[1,0].set_ylabel('Valores sensor')
ax[1,0].set_title ('Gráfica sensor 2')
ax[1,1].scatter(dataframe_banana["Humidity_mean"],dataframe_banana["R2_mean"])
ax[1,1].set_xlabel ('Humedad media')
ax[1,1].set_ylabel('Valores sensor')
ax[1,1].set_title ('Gráfica sensor 2')
ax[2,0].scatter(dataframe_banana["Temp._mean"],dataframe_banana["R3_mean"])
ax[2,0].set_xlabel ('Temperatura media')
ax[2,0].set_ylabel('Valores sensor')
ax[2,0].set_title ('Gráfica sensor 3')
ax[2,1].scatter(dataframe_banana["Humidity_mean"],dataframe_banana["R3_mean"])
ax[2,1].set_xlabel ('Humedad media')
ax[2,1].set_ylabel('Valores sensor')
ax[2,1].set_title ('Gráfica sensor 3')
ax[3,0].scatter(dataframe_banana["Temp._mean"],dataframe_banana["R4_mean"])
ax[3,0].set_xlabel ('Temperatura media')
ax[3,0].set_ylabel('Valores sensor')
ax[3,0].set_title ('Gráfica sensor 4')
ax[3,1].scatter(dataframe_banana["Humidity_mean"],dataframe_banana["R4_mean"])
ax[3,1].set_xlabel ('Humedad media')
ax[3,1].set_ylabel('Valores sensor')
ax[3,1].set_title ('Gráfica sensor 4')
ax[4,0].scatter(dataframe_banana["Temp._mean"],dataframe_banana["R5_mean"])
ax[4,0].set_xlabel ('Temperatura media')
ax[4,0].set_ylabel('Valores sensor')
ax[4,0].set_title ('Gráfica sensor 5')
ax[4,1].scatter(dataframe_banana["Humidity_mean"],dataframe_banana["R5_mean"])
ax[4,1].set_xlabel ('Humedad media')
ax[4,1].set_ylabel('Valores sensor')
ax[4,1].set_title ('Gráfica sensor 5')
ax[5,0].scatter(dataframe_banana["Temp._mean"],dataframe_banana["R6_mean"])
ax[5,0].set_xlabel ('Temperatura media')
ax[5,0].set_ylabel('Valores sensor')
ax[5,0].set_title ('Gráfica sensor 6')
ax[5,1].scatter(dataframe_banana["Humidity_mean"],dataframe_banana["R6_mean"])
ax[5,1].set_xlabel ('Humedad media')
ax[5,1].set_ylabel('Valores sensor')
ax[5,1].set_title ('Gráfica sensor 6')
ax[6,0].scatter(dataframe_banana["Temp._mean"],dataframe_banana["R7_mean"])
ax[6,0].set_xlabel ('Temperatura media')
ax[6,0].set_ylabel('Valores sensor')
ax[6,0].set_title ('Gráfica sensor 7')
ax[6,1].scatter(dataframe_banana["Humidity_mean"],dataframe_banana["R7_mean"])
ax[6,1].set_xlabel ('Humedad media')
ax[6,1].set_ylabel('Valores sensor')
ax[6,1].set_title ('Gráfica sensor 7')
ax[7,0].scatter(dataframe_banana["Temp._mean"],dataframe_banana["R8_mean"])
ax[7,0].set_xlabel ('Temperatura media')
ax[7,0].set_ylabel('Valores sensor')
ax[7,0].set_title ('Gráfica sensor 8')
ax[7,1].scatter(dataframe_banana["Humidity_mean"],dataframe_banana["R8_mean"])
ax[7,1].set_xlabel ('Humedad media')
ax[7,1].set_ylabel('Valores sensor')
ax[7,1].set_title ('Gráfica sensor 1')
# Out:
# Text(0.5, 1.0, 'Gráfica sensor 1')

# %%
fig, ax = plt.subplots(8,2, figsize=(10, 50))
fig.tight_layout()
fig.subplots_adjust(left=0.25, bottom=0.15, hspace=1) 

ax[0,0].scatter(dataframe_wine["Temp._mean"],dataframe_wine["R1_mean"])
ax[0,0].set_xlabel ('Temperatura media')
ax[0,0].set_ylabel('Valores sensor')
ax[0,0].set_title ('Gráfica sensor 1')
ax[0,1].scatter(dataframe_wine["Humidity_mean"],dataframe_wine["R1_mean"])
ax[0,1].set_xlabel ('Humedad media')
ax[0,1].set_ylabel('Valores sensor')
ax[0,1].set_title ('Gráfica sensor 1')
ax[1,0].scatter(dataframe_wine["Temp._mean"],dataframe_wine["R2_mean"])
ax[1,0].set_xlabel ('Temperatura media')
ax[1,0].set_ylabel('Valores sensor')
ax[1,0].set_title ('Gráfica sensor 2')
ax[1,1].scatter(dataframe_wine["Humidity_mean"],dataframe_wine["R2_mean"])
ax[1,1].set_xlabel ('Humedad media')
ax[1,1].set_ylabel('Valores sensor')
ax[1,1].set_title ('Gráfica sensor 2')
ax[2,0].scatter(dataframe_wine["Temp._mean"],dataframe_wine["R3_mean"])
ax[2,0].set_xlabel ('Temperatura media')
ax[2,0].set_ylabel('Valores sensor')
ax[2,0].set_title ('Gráfica sensor 3')
ax[2,1].scatter(dataframe_wine["Humidity_mean"],dataframe_wine["R3_mean"])
ax[2,1].set_xlabel ('Humedad media')
ax[2,1].set_ylabel('Valores sensor')
ax[2,1].set_title ('Gráfica sensor 3')
ax[3,0].scatter(dataframe_wine["Temp._mean"],dataframe_wine["R4_mean"])
ax[3,0].set_xlabel ('Temperatura media')
ax[3,0].set_ylabel('Valores sensor')
ax[3,0].set_title ('Gráfica sensor 4')
ax[3,1].scatter(dataframe_wine["Humidity_mean"],dataframe_wine["R4_mean"])
ax[3,1].set_xlabel ('Humedad media')
ax[3,1].set_ylabel('Valores sensor')
ax[3,1].set_title ('Gráfica sensor 4')
ax[4,0].scatter(dataframe_wine["Temp._mean"],dataframe_wine["R5_mean"])
ax[4,0].set_xlabel ('Temperatura media')
ax[4,0].set_ylabel('Valores sensor')
ax[4,0].set_title ('Gráfica sensor 5')
ax[4,1].scatter(dataframe_wine["Humidity_mean"],dataframe_wine["R5_mean"])
ax[4,1].set_xlabel ('Humedad media')
ax[4,1].set_ylabel('Valores sensor')
ax[4,1].set_title ('Gráfica sensor 5')
ax[5,0].scatter(dataframe_wine["Temp._mean"],dataframe_wine["R6_mean"])
ax[5,0].set_xlabel ('Temperatura media')
ax[5,0].set_ylabel('Valores sensor')
ax[5,0].set_title ('Gráfica sensor 6')
ax[5,1].scatter(dataframe_wine["Humidity_mean"],dataframe_wine["R6_mean"])
ax[5,1].set_xlabel ('Humedad media')
ax[5,1].set_ylabel('Valores sensor')
ax[5,1].set_title ('Gráfica sensor 6')
ax[6,0].scatter(dataframe_wine["Temp._mean"],dataframe_wine["R7_mean"])
ax[6,0].set_xlabel ('Temperatura media')
ax[6,0].set_ylabel('Valores sensor')
ax[6,0].set_title ('Gráfica sensor 7')
ax[6,1].scatter(dataframe_wine["Humidity_mean"],dataframe_wine["R7_mean"])
ax[6,1].set_xlabel ('Humedad media')
ax[6,1].set_ylabel('Valores sensor')
ax[6,1].set_title ('Gráfica sensor 7')
ax[7,0].scatter(dataframe_wine["Temp._mean"],dataframe_wine["R8_mean"])
ax[7,0].set_xlabel ('Temperatura media')
ax[7,0].set_ylabel('Valores sensor')
ax[7,0].set_title ('Gráfica sensor 8')
ax[7,1].scatter(dataframe_wine["Humidity_mean"],dataframe_wine["R8_mean"])
ax[7,1].set_xlabel ('Humedad media')
ax[7,1].set_ylabel('Valores sensor')
ax[7,1].set_title ('Gráfica sensor 8')
# Out:
# Text(0.5, 1.0, 'Gráfica sensor 8')

# %%
sensor_d_temp_max = sensor_d[sensor_d["Temp."] > 28.5]
sensor_d_temp_avg = sensor_d[(25.5 <sensor_d["Temp."]) & (sensor_d["Temp."] < 28.5)]
sensor_d_temp_min = sensor_d[sensor_d["Temp."] < 25.5]

sensor_d_temp_max_banana = sensor_d_temp_max.loc[sensor_d_temp_max['id'].isin(sensor_m[sensor_m['class'] == "banana"]['id'])]
sensor_d_temp_max_wine = sensor_d_temp_max.loc[sensor_d_temp_max['id'].isin(sensor_m[sensor_m['class'] == "wine"]['id'])]
sensor_d_temp_max_background = sensor_d_temp_max.loc[sensor_d_temp_max['id'].isin(sensor_m[sensor_m['class'] == "background"]['id'])]

sensor_d_temp_avg_banana = sensor_d_temp_avg.loc[sensor_d_temp_avg['id'].isin(sensor_m[sensor_m['class'] == "banana"]['id'])]
sensor_d_temp_avg_wine = sensor_d_temp_avg.loc[sensor_d_temp_avg['id'].isin(sensor_m[sensor_m['class'] == "wine"]['id'])]
sensor_d_temp_avg_background = sensor_d_temp_avg.loc[sensor_d_temp_avg['id'].isin(sensor_m[sensor_m['class'] == "background"]['id'])]

sensor_d_temp_min_banana = sensor_d_temp_min.loc[sensor_d_temp_min['id'].isin(sensor_m[sensor_m['class'] == "banana"]['id'])]
sensor_d_temp_min_wine = sensor_d_temp_min.loc[sensor_d_temp_min['id'].isin(sensor_m[sensor_m['class'] == "wine"]['id'])]
sensor_d_temp_min_background = sensor_d_temp_min.loc[sensor_d_temp_min['id'].isin(sensor_m[sensor_m['class'] == "background"]['id'])]

# %%
sensor_d_temp_max_banana.describe()
# Out:
#                  id          time            R1            R2            R3  \
# count  17953.000000  17953.000000  17953.000000  17953.000000  17953.000000
# mean      24.184649     -0.096718     12.132319      8.529204      8.663559
# std       14.001868      0.672174      0.585670      1.407016      1.417566
# min       10.000000     -0.999833     10.792400      5.205400      5.314480
# 25%       15.000000     -0.631354     11.597200      7.150680      7.299250
# 50%       21.000000     -0.248514     12.151700      8.460440      8.492650
# 75%       21.000000      0.278283     12.686200      9.988680     10.138800
# max       60.000000      1.582577     13.143400     10.472600     10.603800
#
#                  R4            R5            R6            R7            R8  \
# count  17953.000000  17953.000000  17953.000000  17953.000000  17953.000000
# mean       9.632520     11.832453     12.785956      4.891994      5.287425
# ...

# %%
sensor_d_temp_avg_banana.describe()
# Out:
#                   id           time             R1             R2  \
# count  271338.000000  271338.000000  271338.000000  271338.000000
# mean       32.593168       0.368461      12.296575       9.004175
# std        20.139956       0.821543       0.780300       1.588582
# min         0.000000      -0.999997       8.654710       3.042710
# 25%        15.000000      -0.328497      11.978600       8.324248
# 50%        34.000000       0.347563      12.499100       9.630055
# 75%        51.000000       1.004825      12.825000      10.153800
# max        65.000000       2.689746      13.733300      11.112300
#
#                   R3             R4            R5             R6  \
# count  271338.000000  271338.000000  271338.00000  271338.000000
# mean        8.984954      10.153405      17.45054      15.248818
# std         1.663256       1.752901      18.66089       2.316632
# min         3.441600       4.050320       1.90129       9.345730
# ...

# %%
sensor_d_temp_min_banana.describe()
# Out:
#                  id          time            R1            R2            R3  \
# count  16153.000000  16153.000000  16153.000000  16153.000000  16153.000000
# mean      41.019749      1.053520     10.915995      8.810647      8.696372
# std       24.430658      0.809504      1.493375      1.422788      1.498402
# min        3.000000     -0.507356      9.254280      7.317160      6.899710
# 25%        3.000000      0.393238      9.677670      7.568690      7.266270
# 50%       57.000000      1.036571     10.200500      8.141420      8.236350
# 75%       57.000000      1.634420     12.964600     10.733300     10.403900
# max       57.000000      2.679756     13.421600     11.315500     11.374200
#
#                  R4            R5            R6            R7            R8  \
# count  16153.000000  16153.000000  16153.000000  16153.000000  16153.000000
# mean       9.939933     24.118263     17.039616      4.406368      5.957119
# ...

# %%
fig, ax = plt.subplots(16,3, figsize=(10, 50))
fig.tight_layout()
fig.subplots_adjust(left=0.25, bottom=0.15, hspace=1) 

ax[0,0].scatter(sensor_d_temp_min_banana["Temp."],sensor_d_temp_min_banana["R1"])
ax[0,0].set_xlabel ('Temperatura')
ax[0,0].set_ylabel('Valores sensor')
ax[0,0].set_title ('Gráfica sensor 1')
ax[0,1].scatter(sensor_d_temp_avg_banana["Temp."],sensor_d_temp_avg_banana["R1"])
ax[0,1].set_xlabel ('Temperatura')
ax[0,1].set_ylabel('Valores sensor')
ax[0,1].set_title ('Gráfica sensor 1')
ax[0,2].scatter(sensor_d_temp_max_banana["Temp."],sensor_d_temp_max_banana["R1"])
ax[0,2].set_xlabel ('Temperatura')
ax[0,2].set_ylabel('Valores sensor')
ax[0,2].set_title ('Gráfica sensor 1')
ax[1,0].scatter(sensor_d_temp_min_banana["Humidity"],sensor_d_temp_min_banana["R1"])
ax[1,0].set_xlabel ('Humedad')
ax[1,0].set_ylabel('Valores sensor')
ax[1,0].set_title ('Gráfica sensor 1')
ax[1,1].scatter(sensor_d_temp_avg_banana["Humidity"],sensor_d_temp_avg_banana["R1"])
ax[1,1].set_xlabel ('Humedad')
ax[1,1].set_ylabel('Valores sensor')
ax[1,1].set_title ('Gráfica sensor 1')
ax[1,2].scatter(sensor_d_temp_max_banana["Humidity"],sensor_d_temp_max_banana["R1"])
ax[1,2].set_xlabel ('Humedad')
ax[1,2].set_ylabel('Valores sensor')
ax[1,2].set_title ('Gráfica sensor 1')
ax[2,0].scatter(sensor_d_temp_min_banana["Temp."],sensor_d_temp_min_banana["R2"])
ax[2,0].set_xlabel ('Temperatura')
ax[2,0].set_ylabel('Valores sensor')
ax[2,0].set_title ('Gráfica sensor 2')
ax[2,1].scatter(sensor_d_temp_avg_banana["Temp."],sensor_d_temp_avg_banana["R2"])
ax[2,1].set_xlabel ('Temperatura')
ax[2,1].set_ylabel('Valores sensor')
ax[2,1].set_title ('Gráfica sensor 2')
ax[2,2].scatter(sensor_d_temp_max_banana["Temp."],sensor_d_temp_max_banana["R2"])
ax[2,2].set_xlabel ('Temperatura')
ax[2,2].set_ylabel('Valores sensor')
ax[2,2].set_title ('Gráfica sensor 2')
ax[3,0].scatter(sensor_d_temp_min_banana["Humidity"],sensor_d_temp_min_banana["R2"])
ax[3,0].set_xlabel ('Humedad')
ax[3,0].set_ylabel('Valores sensor')
ax[3,0].set_title ('Gráfica sensor 2')
ax[3,1].scatter(sensor_d_temp_avg_banana["Humidity"],sensor_d_temp_avg_banana["R2"])
ax[3,1].set_xlabel ('Humedad')
ax[3,1].set_ylabel('Valores sensor')
ax[3,1].set_title ('Gráfica sensor 2')
ax[3,2].scatter(sensor_d_temp_max_banana["Humidity"],sensor_d_temp_max_banana["R2"])
ax[3,2].set_xlabel ('Humedad')
ax[3,2].set_ylabel('Valores sensor')
ax[3,2].set_title ('Gráfica sensor 2')
ax[4,0].scatter(sensor_d_temp_min_banana["Temp."],sensor_d_temp_min_banana["R3"])
ax[4,0].set_xlabel ('Temperatura')
ax[4,0].set_ylabel('Valores sensor')
ax[4,0].set_title ('Gráfica sensor 3')
ax[4,1].scatter(sensor_d_temp_avg_banana["Temp."],sensor_d_temp_avg_banana["R3"])
ax[4,1].set_xlabel ('Temperatura')
ax[4,1].set_ylabel('Valores sensor')
ax[4,1].set_title ('Gráfica sensor 3')
ax[4,2].scatter(sensor_d_temp_max_banana["Temp."],sensor_d_temp_max_banana["R3"])
ax[4,2].set_xlabel ('Temperatura')
ax[4,2].set_ylabel('Valores sensor')
ax[4,2].set_title ('Gráfica sensor 3')
ax[5,0].scatter(sensor_d_temp_min_banana["Humidity"],sensor_d_temp_min_banana["R3"])
ax[5,0].set_xlabel ('Humedad')
ax[5,0].set_ylabel('Valores sensor')
ax[5,0].set_title ('Gráfica sensor 3')
ax[5,1].scatter(sensor_d_temp_avg_banana["Humidity"],sensor_d_temp_avg_banana["R3"])
ax[5,1].set_xlabel ('Humedad')
ax[5,1].set_ylabel('Valores sensor')
ax[5,1].set_title ('Gráfica sensor 3')
ax[5,2].scatter(sensor_d_temp_max_banana["Humidity"],sensor_d_temp_max_banana["R3"])
ax[5,2].set_xlabel ('Humedad')
ax[5,2].set_ylabel('Valores sensor')
ax[5,2].set_title ('Gráfica sensor 3')
ax[6,0].scatter(sensor_d_temp_min_banana["Temp."],sensor_d_temp_min_banana["R4"])
ax[6,0].set_xlabel ('Temperatura')
ax[6,0].set_ylabel('Valores sensor')
ax[6,0].set_title ('Gráfica sensor 4')
ax[6,1].scatter(sensor_d_temp_avg_banana["Temp."],sensor_d_temp_avg_banana["R4"])
ax[6,1].set_xlabel ('Temperatura')
ax[6,1].set_ylabel('Valores sensor')
ax[6,1].set_title ('Gráfica sensor 4')
ax[6,2].scatter(sensor_d_temp_max_banana["Temp."],sensor_d_temp_max_banana["R4"])
ax[6,2].set_xlabel ('Temperatura')
ax[6,2].set_ylabel('Valores sensor')
ax[6,2].set_title ('Gráfica sensor 4')
ax[7,0].scatter(sensor_d_temp_min_banana["Humidity"],sensor_d_temp_min_banana["R4"])
ax[7,0].set_xlabel ('Humedad')
ax[7,0].set_ylabel('Valores sensor')
ax[7,0].set_title ('Gráfica sensor 4')
ax[7,1].scatter(sensor_d_temp_avg_banana["Humidity"],sensor_d_temp_avg_banana["R4"])
ax[7,1].set_xlabel ('Humedad')
ax[7,1].set_ylabel('Valores sensor')
ax[7,1].set_title ('Gráfica sensor 4')
ax[7,2].scatter(sensor_d_temp_max_banana["Humidity"],sensor_d_temp_max_banana["R4"])
ax[7,2].set_xlabel ('Humedad')
ax[7,2].set_ylabel('Valores sensor')
ax[7,2].set_title ('Gráfica sensor 4')
ax[8,0].scatter(sensor_d_temp_min_banana["Temp."],sensor_d_temp_min_banana["R5"])
ax[8,0].set_xlabel ('Temperatura')
ax[8,0].set_ylabel('Valores sensor')
ax[8,0].set_title ('Gráfica sensor 5')
ax[8,1].scatter(sensor_d_temp_avg_banana["Temp."],sensor_d_temp_avg_banana["R5"])
ax[8,1].set_xlabel ('Temperatura')
ax[8,1].set_ylabel('Valores sensor')
ax[8,1].set_title ('Gráfica sensor 5')
ax[8,2].scatter(sensor_d_temp_max_banana["Temp."],sensor_d_temp_max_banana["R5"])
ax[8,2].set_xlabel ('Temperatura')
ax[8,2].set_ylabel('Valores sensor')
ax[8,2].set_title ('Gráfica sensor 5')
ax[9,0].scatter(sensor_d_temp_min_banana["Humidity"],sensor_d_temp_min_banana["R5"])
ax[9,0].set_xlabel ('Humedad')
ax[9,0].set_ylabel('Valores sensor')
ax[9,0].set_title ('Gráfica sensor 5')
ax[9,1].scatter(sensor_d_temp_avg_banana["Humidity"],sensor_d_temp_avg_banana["R5"])
ax[9,1].set_xlabel ('Humedad')
ax[9,1].set_ylabel('Valores sensor')
ax[9,1].set_title ('Gráfica sensor 5')
ax[9,2].scatter(sensor_d_temp_max_banana["Humidity"],sensor_d_temp_max_banana["R5"])
ax[9,2].set_xlabel ('Humedad')
ax[9,2].set_ylabel('Valores sensor')
ax[9,2].set_title ('Gráfica sensor 5')
ax[10,0].scatter(sensor_d_temp_min_banana["Temp."],sensor_d_temp_min_banana["R6"])
ax[10,0].set_xlabel ('Temperatura')
ax[10,0].set_ylabel('Valores sensor')
ax[10,0].set_title ('Gráfica sensor 6')
ax[10,1].scatter(sensor_d_temp_avg_banana["Temp."],sensor_d_temp_avg_banana["R6"])
ax[10,1].set_xlabel ('Temperatura')
ax[10,1].set_ylabel('Valores sensor')
ax[10,1].set_title ('Gráfica sensor 6')
ax[10,2].scatter(sensor_d_temp_max_banana["Temp."],sensor_d_temp_max_banana["R6"])
ax[10,2].set_xlabel ('Temperatura')
ax[10,2].set_ylabel('Valores sensor')
ax[10,2].set_title ('Gráfica sensor 6')
ax[11,0].scatter(sensor_d_temp_min_banana["Humidity"],sensor_d_temp_min_banana["R6"])
ax[11,0].set_xlabel ('Humedad')
ax[11,0].set_ylabel('Valores sensor')
ax[11,0].set_title ('Gráfica sensor 6')
ax[11,1].scatter(sensor_d_temp_avg_banana["Humidity"],sensor_d_temp_avg_banana["R6"])
ax[11,1].set_xlabel ('Humedad')
ax[11,1].set_ylabel('Valores sensor')
ax[11,1].set_title ('Gráfica sensor 6')
ax[11,2].scatter(sensor_d_temp_max_banana["Humidity"],sensor_d_temp_max_banana["R6"])
ax[11,2].set_xlabel ('Humedad')
ax[11,2].set_ylabel('Valores sensor')
ax[11,2].set_title ('Gráfica sensor 6')
ax[12,0].scatter(sensor_d_temp_min_banana["Temp."],sensor_d_temp_min_banana["R7"])
ax[12,0].set_xlabel ('Temperatura')
ax[12,0].set_ylabel('Valores sensor')
ax[12,0].set_title ('Gráfica sensor 7')
ax[12,1].scatter(sensor_d_temp_avg_banana["Temp."],sensor_d_temp_avg_banana["R7"])
ax[12,1].set_xlabel ('Temperatura')
ax[12,1].set_ylabel('Valores sensor')
ax[12,1].set_title ('Gráfica sensor 7')
ax[12,2].scatter(sensor_d_temp_max_banana["Temp."],sensor_d_temp_max_banana["R7"])
ax[12,2].set_xlabel ('Temperatura')
ax[12,2].set_ylabel('Valores sensor')
ax[12,2].set_title ('Gráfica sensor 7')
ax[13,0].scatter(sensor_d_temp_min_banana["Humidity"],sensor_d_temp_min_banana["R7"])
ax[13,0].set_xlabel ('Humedad')
ax[13,0].set_ylabel('Valores sensor')
ax[13,0].set_title ('Gráfica sensor 7')
ax[13,1].scatter(sensor_d_temp_avg_banana["Humidity"],sensor_d_temp_avg_banana["R7"])
ax[13,1].set_xlabel ('Humedad')
ax[13,1].set_ylabel('Valores sensor')
ax[13,1].set_title ('Gráfica sensor 7')
ax[13,2].scatter(sensor_d_temp_max_banana["Humidity"],sensor_d_temp_max_banana["R7"])
ax[13,2].set_xlabel ('Humedad')
ax[13,2].set_ylabel('Valores sensor')
ax[13,2].set_title ('Gráfica sensor 7')
ax[14,0].scatter(sensor_d_temp_min_banana["Temp."],sensor_d_temp_min_banana["R8"])
ax[14,0].set_xlabel ('Temperatura')
ax[14,0].set_ylabel('Valores sensor')
ax[14,0].set_title ('Gráfica sensor 8')
ax[14,1].scatter(sensor_d_temp_avg_banana["Temp."],sensor_d_temp_avg_banana["R8"])
ax[14,1].set_xlabel ('Temperatura')
ax[14,1].set_ylabel('Valores sensor')
ax[14,1].set_title ('Gráfica sensor 8')
ax[14,2].scatter(sensor_d_temp_max_banana["Temp."],sensor_d_temp_max_banana["R8"])
ax[14,2].set_xlabel ('Temperatura')
ax[14,2].set_ylabel('Valores sensor')
ax[14,2].set_title ('Gráfica sensor 8')
ax[15,0].scatter(sensor_d_temp_min_banana["Humidity"],sensor_d_temp_min_banana["R8"])
ax[15,0].set_xlabel ('Humedad')
ax[15,0].set_ylabel('Valores sensor')
ax[15,0].set_title ('Gráfica sensor 8')
ax[15,1].scatter(sensor_d_temp_avg_banana["Humidity"],sensor_d_temp_avg_banana["R8"])
ax[15,1].set_xlabel ('Humedad')
ax[15,1].set_ylabel('Valores sensor')
ax[15,1].set_title ('Gráfica sensor 8')
ax[15,2].scatter(sensor_d_temp_max_banana["Humidity"],sensor_d_temp_max_banana["R8"])
ax[15,2].set_xlabel ('Humedad')
ax[15,2].set_ylabel('Valores sensor')
ax[15,2].set_title ('Gráfica sensor 8')
# Out:
# Text(0.5, 1.0, 'Gráfica sensor 8')
